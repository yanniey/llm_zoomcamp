# %% [markdown]
# Instead of using in-memory knowledge base (KB), use sqlite to persist the KB

# %%
from ingest import load_faq_data
documents = load_faq_data()

# %%
docs_llm = [doc for doc in documents if doc['course']=='llm-zoomcamp']
print(f'LLM Zoomcamp: {len(docs_llm)} docs')
# Out:
# LLM Zoomcamp: 85 docs

# %%
from
