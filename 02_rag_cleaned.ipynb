# %% [markdown]
# compared to 01 notebook, the functions are now split out so that this notebook is more modular

# %%
from rag_helper import RAGBase
from ingest import load_faq_data, build_index
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv() # read local api file for openai
openai_client = OpenAI()

# %%
documents = load_faq_data()
index = build_index(documents)

# %%
assistant = RAGBase(index = index, llm_client=openai_client)
assistant.rag("can i still sign up to the course")
# Out:
# 'Yes, you can still join the course.\n\nIf you want a certificate, you’ll need to submit your project while submissions are still open.'
